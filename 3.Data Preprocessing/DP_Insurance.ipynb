# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder,StandardScaler

df=pd.read_csv("/Users/samarthgarg/Downloads/ML ETP/DataSets/insurance.csv")
df.shape
# Out:
# (1338, 7)

# %%
# Separate numerical and categorical columns
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
cat_cols = df.select_dtypes(include=['object']).columns

# %%
# # Encode categorical variables using Label Encoding
# le = LabelEncoder()
# for col in cat_cols:
#     df[col] = le.fit_transform(df[col])
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/35/d_vjy7gs7fx9z9ls9ftyw4s40000gn/T/ipykernel_1311/3050997403.py in ?()
#       1 # # Encode categorical variables using Label Encoding
#       2 le = LabelEncoder()
#       3 # for col in cat_cols:
#       4 #     df[col] = le.fit_transform(df[col])
# ----> 5 df[cat_cols] = le.fit_transform(df[cat_cols])
#       6 df
#
# /opt/homebrew/lib/python3.14/site-packages/pandas/core/frame.py in ?(self, key)
#    4096             return self._getitem_slice(key)
#    4097
#    4098         # Do we have a (boolean) DataFrame?
#    4099         if isinstance(key, DataFrame):
# -> 4100             return self.where(key)
#    4101
#    4102         # Do we have a (boolean) 1d indexer?
#    4103         if com.is_bool_indexer(key):
#
# /opt/homebrew/lib/python3.14/site-packages/pandas/core/generic.py in ?(self, cond, other, inplace, axis, level)
#   11044                         stacklevel=2,
#   11045                     )
#   11046
#   11047         other = common.apply_if_callable(other, self)
# > 11048         return self._where(cond, other, inplace, axis, level)
#
# /opt/homebrew/lib/python3.14/site-packages/pandas/core/generic.py in ?(self, cond, other, inplace, axis, level, warn)
#   10732                     raise ValueError(msg.format(dtype=cond.dtype))
#   10733             else:
#   10734                 for _dt in cond.dtypes:
#   10735                     if not is_bool_dtype(_dt):
# > 10736                         raise ValueError(msg.format(dtype=_dt))
#   10737                 if cond._mgr.any_extension_types:
#   10738                     # GH51574: avoid object ndarray conversion later on
#   10739                     cond = cond._constructor(
#
# ValueError: Boolean array expected for the condition, not object

# %%
# One-Hot Encoding
df = pd.get_dummies(df)
df
# Out:
#       age     bmi  children      charges  sex_female  sex_male  smoker_no  \
# 0      19  27.900         0  16884.92400        True     False      False
# 1      18  33.770         1   1725.55230       False      True       True
# 2      28  33.000         3   4449.46200       False      True       True
# 3      33  22.705         0  21984.47061       False      True       True
# 4      32  28.880         0   3866.85520       False      True       True
# ...   ...     ...       ...          ...         ...       ...        ...
# 1333   50  30.970         3  10600.54830       False      True       True
# 1334   18  31.920         0   2205.98080        True     False       True
# 1335   18  36.850         0   1629.83350        True     False       True
# 1336   21  25.800         0   2007.94500        True     False       True
# 1337   61  29.070         0  29141.36030        True     False      False
#
#       smoker_yes  region_northeast  region_northwest  region_southeast  \
# 0           True             False             False             False
# 1          False             False             False              True
# 2          False             False             False              True
# 3          False             False              True             False
# 4          False             False              True             False
# ...          ...               ...               ...               ...
# 1333       False             False              True             False
# 1334       False              True             False             False
# 1335       False             False             False              True
# 1336       False             False             False             False
# 1337        True             False              True             False
#
#       region_southwest
# 0                 True
# 1                False
# 2                False
# 3                False
# 4                False
# ...                ...
# 1333             False
# 1334             False
# 1335             False
# 1336              True
# 1337             False
#
# [1338 rows x 12 columns]

# %%
# Feature scaling using StandardScaler
scaler = StandardScaler()
df[num_cols] = scaler.fit_transform(df[num_cols])
df
# Out:
#            age       bmi  children   charges  sex_female  sex_male  smoker_no  \
# 0    -1.438764 -0.453320 -0.908614  0.298584        True     False      False
# 1    -1.509965  0.509621 -0.078767 -0.953689       False      True       True
# 2    -0.797954  0.383307  1.580926 -0.728675       False      True       True
# 3    -0.441948 -1.305531 -0.908614  0.719843       False      True       True
# 4    -0.513149 -0.292556 -0.908614 -0.776802       False      True       True
# ...        ...       ...       ...       ...         ...       ...        ...
# 1333  0.768473  0.050297  1.580926 -0.220551       False      True       True
# 1334 -1.509965  0.206139 -0.908614 -0.914002        True     False       True
# 1335 -1.509965  1.014878 -0.908614 -0.961596        True     False       True
# 1336 -1.296362 -0.797813 -0.908614 -0.930362        True     False       True
# 1337  1.551686 -0.261388 -0.908614  1.311053        True     False      False
#
#       smoker_yes  region_northeast  region_northwest  region_southeast  \
# 0           True             False             False             False
# 1          False             False             False              True
# 2          False             False             False              True
# 3          False             False              True             False
# 4          False             False              True             False
# ...          ...               ...               ...               ...
# 1333       False             False              True             False
# 1334       False              True             False             False
# 1335       False             False             False              True
# 1336       False             False             False             False
# 1337        True             False              True             False
#
#       region_southwest
# 0                 True
# 1                False
# 2                False
# 3                False
# 4                False
# ...                ...
# 1333             False
# 1334             False
# 1335             False
# 1336              True
# 1337             False
#
# [1338 rows x 12 columns]
